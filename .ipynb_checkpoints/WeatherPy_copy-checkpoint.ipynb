# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Looking at the first plot we confirm what is already commonly understood, cities closer to latitude zero are warmer than cities further away from the equator.
# * Another important aspect of the first plot is that northen hemisphere is currently colder. Being that it is currently winter on the northen hemisphere temperatures on the northen hemisphere are generaly colder than those in similar latitudes on the southern hemisphere.
# * Looking at the second plot I have to say that there is no correlation between clodiness percentage and latitude. Plot is generally all over the place.
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
#import api_keys
from config import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=150)
lngs = np.random.uniform(low=-180.000, high=180.000, size=150)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Total number of cities is {len(cities)}")
print(cities)
# Out:
# Total number of cities is 112
# ['malaya serdoba', 'hermanus', 'oum hadjer', 'gurskoye', 'ushuaia', 'namibe', 'maghama', 'coffs harbour', 'kondinskoye', 'saskylakh', 'albany', 'georgetown', 'luanda', 'tiksi', 'new norfolk', 'nizhniy kuranakh', 'tuatapere', 'santa maria', 'qaanaaq', 'rawson', 'arraial do cabo', 'hede', 'butaritari', 'keningau', 'punta arenas', 'hoopstad', 'lasa', 'hobart', 'okhotsk', 'jamestown', 'hilo', 'provideniya', 'haines junction', 'pevek', 'mataura', 'busselton', 'bereznik', 'mys shmidta', 'bredasdorp', 'lebu', 'nanortalik', 'atuona', 'cayenne', 'aklavik', 'cherskiy', 'cape town', 'barentsburg', 'chokurdakh', 'khatanga', 'castro', 'port keats', 'beloha', 'shimoda', 'esna', 'saryshagan', 'illoqqortoormiut', 'pangnirtung', 'port elizabeth', 'marsh harbour', 'esperance', 'belushya guba', 'rio gallegos', 'mega', 'saldanha', 'ponta delgada', 'qui nhon', 'faanui', 'kavieng', 'rajsamand', 'bengkulu', 'bilma', 'puerto ayora', 'dwarka', 'port lincoln', 'taltal', 'narsaq', 'rikitea', 'katsuura', 'norman wells', 'souillac', 'shanhetun', 'wilkie', 'betioky', 'bluff', 'vaini', 'port alfred', 'millinocket', 'vila franca do campo', 'scottsbluff', 'yellowknife', 'bagar', 'san quintin', 'banda aceh', 'yeletskiy', 'toliary', 'chuy', 'dikson', 'kruisfontein', 'hovd', 'pangody', 'hobyo', 'hithadhoo', 'ryotsu', 'burns lake', 'ola', 'sao joao da barra', 'rossano', 'xinzhou', 'barrow', 'biltine', 'samalaeulu', 'terney']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

ciudades = []
lat = []
temp = []
humid = []
clouds = []
winds = []

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    if '404' in response.values():
        print(f"Sorry city of {city} not found, error 404")
    elif '500' in response.values():
        print("Internal error: 500001 , error 500")
    else:
        print(f"Getting weather data for city of {city}")
        ciudades.append(city)
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        winds.append(response['wind']['speed'])
# Out:
# Getting weather data for city of malaya serdoba
# Getting weather data for city of hermanus
# Getting weather data for city of oum hadjer
# Sorry city of gurskoye not found, error 404
# Getting weather data for city of ushuaia
# Getting weather data for city of namibe
# Sorry city of maghama not found, error 404
# Getting weather data for city of coffs harbour
# Getting weather data for city of kondinskoye
# Getting weather data for city of saskylakh
# Getting weather data for city of albany
# Getting weather data for city of georgetown
# Getting weather data for city of luanda
# Getting weather data for city of tiksi
# Getting weather data for city of new norfolk
# Getting weather data for city of nizhniy kuranakh
# Getting weather data for city of tuatapere
# Getting weather data for city of santa maria
# Getting weather data for city of qaanaaq
# Getting weather data for city of rawson
# Getting weather data for city of arraial do cabo
# Getting weather data for city of hede
# Getting weather data for city of butaritari
# Getting weather data for city of keningau
# Getting weather data for city of punta arenas
# Getting weather data for city of hoopstad
# Internal error: 500001 , error 500
# Getting weather data for city of hobart
# Getting weather data for city of okhotsk
# Getting weather data for city of jamestown
# Getting weather data for city of hilo
# Getting weather data for city of provideniya
# Getting weather data for city of haines junction
# Getting weather data for city of pevek
# Getting weather data for city of mataura
# Getting weather data for city of busselton
# Getting weather data for city of bereznik
# Sorry city of mys shmidta not found, error 404
# Getting weather data for city of bredasdorp
# Internal error: 500001 , error 500
# Internal error: 500001 , error 500
# Getting weather data for city of atuona
# Getting weather data for city of cayenne
# Getting weather data for city of aklavik
# Getting weather data for city of cherskiy
# Getting weather data for city of cape town
# Sorry city of barentsburg not found, error 404
# Getting weather data for city of chokurdakh
# Getting weather data for city of khatanga
# Getting weather data for city of castro
# Getting weather data for city of port keats
# Getting weather data for city of beloha
# Getting weather data for city of shimoda
# Getting weather data for city of esna
# Sorry city of saryshagan not found, error 404
# Sorry city of illoqqortoormiut not found, error 404
# Getting weather data for city of pangnirtung
# Getting weather data for city of port elizabeth
# Getting weather data for city of marsh harbour
# Getting weather data for city of esperance
# Sorry city of belushya guba not found, error 404
# Getting weather data for city of rio gallegos
# Getting weather data for city of mega
# Getting weather data for city of saldanha
# Getting weather data for city of ponta delgada
# Sorry city of qui nhon not found, error 404
# Getting weather data for city of faanui
# Getting weather data for city of kavieng
# Getting weather data for city of rajsamand
# Sorry city of bengkulu not found, error 404
# Getting weather data for city of bilma
# Getting weather data for city of puerto ayora
# Getting weather data for city of dwarka
# Getting weather data for city of port lincoln
# Getting weather data for city of taltal
# Getting weather data for city of narsaq
# Getting weather data for city of rikitea
# Getting weather data for city of katsuura
# Getting weather data for city of norman wells
# Getting weather data for city of souillac
# Getting weather data for city of shanhetun
# Getting weather data for city of wilkie
# Sorry city of betioky not found, error 404
# Getting weather data for city of bluff
# Getting weather data for city of vaini
# Getting weather data for city of port alfred
# Getting weather data for city of millinocket
# Getting weather data for city of vila franca do campo
# Getting weather data for city of scottsbluff
# Getting weather data for city of yellowknife
# Getting weather data for city of bagar
# Getting weather data for city of san quintin
# Getting weather data for city of banda aceh
# Sorry city of yeletskiy not found, error 404
# Sorry city of toliary not found, error 404
# Getting weather data for city of chuy
# Getting weather data for city of dikson
# Getting weather data for city of kruisfontein
# Getting weather data for city of hovd
# Getting weather data for city of pangody
# Getting weather data for city of hobyo
# Getting weather data for city of hithadhoo
# Getting weather data for city of ryotsu
# Getting weather data for city of burns lake
# Getting weather data for city of ola
# Getting weather data for city of sao joao da barra
# Getting weather data for city of rossano
# Getting weather data for city of xinzhou
# Getting weather data for city of barrow
# Getting weather data for city of biltine
# Sorry city of samalaeulu not found, error 404
# Getting weather data for city of terney

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": ciudades,
    "latitude": lat,
    "temperature": temp,
    "humidity": humid,
    "cloudiness": clouds,
    "windspeed": winds
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                     city  latitude  temperature  humidity  cloudiness  \
# 0         malaya serdoba     52.47         3.35        82          68
# 1               hermanus    -34.42        52.54        97           0
# 2             oum hadjer     13.30        62.26        52           0
# 3                ushuaia    -54.81        59.00        47          40
# 4                 namibe    -15.19        73.60       100           0
# 5          coffs harbour    -30.30        81.25        61          40
# 6            kondinskoye     59.65        -7.95        64          68
# 7              saskylakh     71.97       -43.18         0          56
# 8                 albany     42.65        21.47        59          75
# 9             georgetown      6.80        78.37        94          20
# 10                luanda     -8.83        78.80        78          75
# 11                 tiksi     71.64       -34.14        61          76
# 12           new norfolk    -42.78        69.80        46          40
# 13      nizhniy kuranakh     58.84         8.26        83          80
# 14             tuatapere    -46.13        55.69        94          88
# 15           santa maria    -29.69        70.54        91          76
# 16               qaanaaq     77.48       -18.25       100          24
# 17                rawson    -43.30        66.58        25           0
# 18       arraial do cabo    -22.97        77.00        78           0
# 19                  hede     60.45        30.20        92          64
# 20            butaritari      3.07        85.34        99          56
# 21              keningau      5.33        84.20        70          75
# 22          punta arenas    -53.16        57.20        54           0
# 23              hoopstad    -27.83        68.60        50           0
# 24                hobart    -42.88        69.80        52          75
# 25               okhotsk     59.36       -11.82       100           0
# 26             jamestown    -33.21        74.77        71           0
# 27                  hilo     19.71        78.08        66          20
# 28           provideniya     64.42        -0.41        64           0
# 29       haines junction     60.75       -37.51        65           8
# ..                   ...       ...          ...       ...         ...
# 66          norman wells     65.28       -34.61        73          75
# 67              souillac     45.60        32.00        73           0
# 68             shanhetun     44.70        -4.17        52           0
# 69                wilkie     52.41         8.60        78          90
# 70                 bluff    -23.58        77.65        84          88
# 71                 vaini     15.34        55.10        81           0
# 72           port alfred    -33.59        67.03        92          48
# 73           millinocket     45.66        19.83        77          90
# 74  vila franca do campo     37.72        57.20        87          75
# 75           scottsbluff     41.87        41.70        56           1
# 76           yellowknife     62.45        -9.41        76          90
# 77                 bagar     28.19        43.40        74          12
# 78           san quintin     17.54        66.85        78           0
# 79            banda aceh      5.56        73.64        99          36
# 80                  chuy    -33.69        67.30       100          92
# 81                dikson     73.51       -18.66       100          24
# 82          kruisfontein    -34.00        64.37        91          20
# 83                  hovd     63.83        39.20        93          75
# 84               pangody     65.85       -24.46        37          24
# 85                 hobyo      5.35        76.97        84          68
# 86             hithadhoo     -0.60        80.80       100          76
# 87                ryotsu     38.08        41.00        60          75
# 88            burns lake     54.23        21.13        90          44
# 89                   ola     59.58        -0.39       100           8
# 90     sao joao da barra    -21.64        79.27        97           0
# 91               rossano     39.57        24.80        92          90
# 92               xinzhou     38.41         7.54        75           0
# 93                barrow    -38.31        54.74        75           0
# 94               biltine     14.53        63.16        29           0
# 95                terney     45.05        19.60       100           0
#
#     windspeed
# 0        7.85
# 1        3.71
# 2        3.83
# 3       20.80
# 4        3.38
# 5       16.11
# 6        3.38
# 7        3.15
# 8       16.11
# 9        4.70
# 10       5.82
# 11       3.38
# 12       6.93
# 13       4.38
# 14      18.03
# 15       3.04
# 16       8.52
# 17       6.40
# 18      19.46
# 19       3.36
# 20       9.31
# 21       5.82
# 22      28.86
# 23       9.98
# 24       8.05
# 25      10.20
# 26       6.62
# 27      13.87
# 28      11.18
# 29       2.15
# ..        ...
# 66       6.93
# 67       3.36
# 68       2.82
# 69       4.70
# 70       9.64
# 71       2.37
# 72       9.53
# 73       9.17
# 74      18.34
# 75       9.17
# 76      17.22
# 77       5.17
# 78       4.38
# 79       3.27
# 80       4.72
# 81       6.29
# 82       7.18
# 83      39.15
# 84       8.19
# 85      18.37
# 86       3.60
# 87      24.16
# 88       2.26
# 89      11.43
# 90      12.33
# 91      13.87
# 92       2.59
# 93       2.59
# 94       9.98
# 95      15.23
#
# [96 rows x 6 columns]

# %%
weather_data.shape
# Out:
# (96, 6)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["latitude"], weather_data["temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("charts/TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["latitude"], weather_data["humidity"], marker="o")

# Incorporate the other graph properties
plt.title("Humidity in World Cities")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("charts/HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["latitude"], weather_data["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("charts/CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["latitude"], weather_data["windspeed"], marker="o")

# Incorporate the other graph properties
plt.title("Windspeed in World Cities")
plt.ylabel("Windspeed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("charts/WindspeedInWorldCities.png")

# Show plot
plt.show()
